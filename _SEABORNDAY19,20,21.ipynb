# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
x = np.random.randn(1000)
plt.figure(dpi=150)
sns.distplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
x = np.random.randn(1000)
plt.figure(dpi=150)
sns.distplot(x,color = 'green',hist = False)
# Out:
# <Axes: ylabel='Density'>

# %%
x = np.random.randn(1000)
plt.figure(dpi=150)
sns.distplot(x,color = 'green',hist = False,vertical=True)
# Out:
# <Axes: xlabel='Density'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')
plt.figure(dpi=100)
sns.distplot(x,color = 'green', hist = False)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.style.use('seaborn-v0_8-pastel')
plt.figure(dpi=100)
sns.distplot(x,color = 'black', hist= False)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # PROJECT

# %%
df_auto = pd.read_csv('Automobile_data.csv')
df_auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ## PREPROCESSING

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df_auto.nunique()
# Out:
# symboling              6
# normalized-losses     52
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           3
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# horsepower            60
# peak-rpm              24
# city-mpg              29
# highway-mpg           30
# price                187
# dtype: int64

# %%
df_auto['symboling'].unique()             # use index method if special characters present
# Out:
# array([ 3,  1,  2,  0, -1, -2])

# %%
df_auto['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df_auto['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df_auto['fuel-type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
# create a function which takes all unique values in one single loop - HW

# %%
def unique_values(lst):
    unique = []

    for value in lst:
        if value not in unique:
            unique.append(value)

    return unique


l = [10, 20, 10, 30, 20, 40, 10, 50]

print(unique_values(l))
# Out:
# [10, 20, 30, 40, 50]

# %%
df_auto.replace('?',np.nan, inplace=True)
df_auto
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df_auto.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df_auto.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
df_auto['price']= df_auto['price'].apply(float)
df_auto['normalized-losses']= df_auto['normalized-losses'].apply(float)
df_auto['horsepower']= df_auto['horsepower'].apply(float)
df_auto['peak-rpm']= df_auto['peak-rpm'].apply(float)

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df_auto.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
df_auto.duplicated().sum()
# Out:
# np.int64(0)

# %%
avg_normalized_losses = df_auto['normalized-losses'].mean()
df_auto['normalized-losses'].replace(np.nan, avg_normalized_losses, inplace=True)

avg_price = df_auto['price'].mean()
df_auto['price'].replace(np.nan, avg_price, inplace=True)

# %%
df_auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
fre_door = df_auto['num-of-doors'].dropna().mode()
fre_door
# Out:
# 0    four
# Name: num-of-doors, dtype: object

# %%
fre_door = df_auto['num-of-doors'].dropna().mode()[0]
fre_door
# Out:
# 'four'

# %%
fre_door = df_auto['num-of-doors'].dropna().mode()[0]
df_auto['num-of-doors'].replace(np.nan,fre_door, inplace=True)

fre_bore = df_auto['bore'].dropna().mode()[0]
df_auto['bore'].replace(np.nan,fre_bore, inplace=True)

fre_stroke = df_auto['stroke'].dropna().mode()[0]
df_auto['stroke'].replace(np.nan,fre_stroke, inplace=True)

fre_horsepower = df_auto['horsepower'].dropna().mode()[0]
df_auto['horsepower'].replace(np.nan,fre_horsepower, inplace=True)

fre_peak_rpm = df_auto['peak-rpm'].dropna().mode()[0]
df_auto['peak-rpm'].replace(np.nan,fre_peak_rpm, inplace=True)

# %%
df_auto.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ## EXPLOLATERY DATA ANALYSIS

# %% [markdown]
# ### DIST PLOT

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.distplot(df_auto.price)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.distplot(df_auto.price,hist=False)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ### LINE PLOT

# %% [markdown]
# - 1-Numerical 2-Numerical

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='engine-size',y='curb-weight',data=df_auto)
# Out:
# <Axes: xlabel='engine-size', ylabel='curb-weight'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='engine-size',y='horsepower',data=df_auto)
# Out:
# <Axes: xlabel='engine-size', ylabel='horsepower'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='horsepower',y='city-mpg',data=df_auto,color='orange',linewidth=3)
# Out:
# <Axes: xlabel='horsepower', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='horsepower',y='city-mpg',data=df_auto,hue='fuel-type')
# Out:
# <Axes: xlabel='horsepower', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='fuel-type')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='drive-wheels')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='engine-location')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='body-style')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='drive-wheels',style='fuel-type')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='drive-wheels',style='fuel-type',markers=True)
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='fuel-type',style='fuel-type',markers=['*','^'])
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.lineplot(x='curb-weight',y='city-mpg',data=df_auto,hue='fuel-type',style='fuel-type',markers=['*','^'])
plt.title('Curb weight Vs City MPG')
plt.xlabel('Curb Weight')
plt.ylabel('City Mpg')
# Out:
# Text(0, 0.5, 'City Mpg')

# %% [markdown]
# # SCATTER PLOT

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.scatterplot(x='engine-size',y='curb-weight',data=df_auto)
# Out:
# <Axes: xlabel='engine-size', ylabel='curb-weight'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.scatterplot(x='engine-size',y='horsepower',data=df_auto)
# Out:
# <Axes: xlabel='engine-size', ylabel='horsepower'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.scatterplot(x='horsepower',y='city-mpg',data=df_auto,color='orange',linewidth=3)
# Out:
# <Axes: xlabel='horsepower', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.scatterplot(x='horsepower',y='city-mpg',data=df_auto,hue='fuel-type')
# Out:
# <Axes: xlabel='horsepower', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.scatterplot(x='curb-weight',y='city-mpg',data=df_auto,hue='fuel-type')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.scatterplot(x='curb-weight',y='city-mpg',data=df_auto,hue='drive-wheels')
# Out:
# <Axes: xlabel='curb-weight', ylabel='city-mpg'>

# %% [markdown]
# # BAR PLOT

# %% [markdown]
# - 1-NUMERICAL 2-CATEGORICAL

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.barplot(x='body-style',y='city-mpg',data=df_auto)
# Out:
# <Axes: xlabel='body-style', ylabel='city-mpg'>

# %%
df_auto.groupby(by='body-style')['city-mpg'].mean()
# Out:
# body-style
# convertible    20.500000
# hardtop        21.625000
# hatchback      26.314286
# sedan          25.322917
# wagon          24.040000
# Name: city-mpg, dtype: float64

# %%
df_auto.groupby(by='body-style')['city-mpg'].mean().sort_values()
# Out:
# body-style
# convertible    20.500000
# hardtop        21.625000
# wagon          24.040000
# sedan          25.322917
# hatchback      26.314286
# Name: city-mpg, dtype: float64

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.barplot(x='fuel-type',y='city-mpg',data=df_auto)
# Out:
# <Axes: xlabel='fuel-type', ylabel='city-mpg'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.barplot(x='body-style',y='price',data=df_auto)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.barplot(x='price',y='body-style',data=df_auto)
# Out:
# <Axes: xlabel='price', ylabel='body-style'>

# %%
plt.figure(figsize = (8,3),dpi=200)
sns.barplot(x='price',y='num-of-cylinders',data=df_auto)
# Out:
# <Axes: xlabel='price', ylabel='num-of-cylinders'>

# %%
order = df_auto.groupby(by = 'num-of-cylinders')['price'].mean().sort_values().index
order
# Out:
# Index(['three', 'four', 'two', 'five', 'six', 'eight', 'twelve'], dtype='object', name='num-of-cylinders')

# %%
# IMP INTERVIEW QUESTION

plt.figure(figsize = (8,3),dpi=200)
sns.barplot(x='price',y='num-of-cylinders',data=df_auto,order=order)
# Out:
# <Axes: xlabel='price', ylabel='num-of-cylinders'>

# %% [markdown]
# # BOX PLOT
# 1-NUMERICAL
# 2-CATEGORICAL

# %%
plt.figure(figsize = (8,3),dpi=200)
sns.boxplot(x='price',data=df_auto)
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize = (8,3),dpi=200)
sns.boxplot(y='price',data=df_auto)
# Out:
# <Axes: ylabel='price'>

# %%
df_auto.price.quantile(.25)
# Out:
# np.float64(7788.0)

# %%
df_auto.price.quantile(.5)
# Out:
# np.float64(10595.0)

# %%
df_auto.price.quantile(.75)
# Out:
# np.float64(16500.0)

# %%
df_auto.price.quantile(1)
# Out:
# np.float64(45400.0)

# %%
plt.figure(figsize = (8,3),dpi=200)
sns.boxplot(x='body-style',y='city-mpg',data=df_auto)
# Out:
# <Axes: xlabel='body-style', ylabel='city-mpg'>

# %% [markdown]
# ## COUNT PLOT
# 1-Categorical

# %%
plt.figure(figsize = (8,3),dpi=200)
sns.countplot(x='body-style',data=df_auto)
# Out:
# <Axes: xlabel='body-style', ylabel='count'>

# %%
df_auto['body-style'].value_counts()
# Out:
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,3),dpi=200)
sns.countplot(x='fuel-type',data=df_auto)
# Out:
# <Axes: xlabel='fuel-type', ylabel='count'>

# %%
plt.figure(dpi=500)
sns.pairplot(df_auto)
