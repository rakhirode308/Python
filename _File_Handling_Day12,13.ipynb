# %%
f = open('abc.txt')           # read mode by default
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open('abc.txt')           # read mode by default
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
f = open('abc.txt','w')                      # write mode

# %%
f.write('Baba baba black sheep')
# Out:
# 21

# %%
f.close()

# %%
f = open('abc.txt','w')

# %%
f.write('Baba baba black sheep')
f.write('Have you any wool')
f.write('Yes sir yes sir three bags full')           # outoup will be lengh of last string
# Out:
# 31

# %%
f.close()

# %%
f = open('abc.txt','a')

# %%
f.write('Baba baba black sheep')
f.write('Have you any wool')
f.write('Yes sir yes sir three bags full')
# Out:
# 31

# %%
f.close()

# %%
f = open('abc.txt')

# %%
f.readline()
# Out:
# 'Baba baba black sheepHave you any woolYes sir yes sir three bags fullBaba baba black sheepHave you any woolYes sir yes sir three bags full'
