# %% [markdown]
# ## PANDAS
# - PANDAS IS A FAST , POWERFUL AND EASY TO USE OPEN SOURCE DATA ANALYSIS AND MANUPULATION LIBRARY.
#     - SERIES
#     - DATA FRAME

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## SERIES

# %%
data = [10,20,30,40,50]
s1 = pd.Series(data)
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
list(s1.index)
# Out:
# [0, 1, 2, 3, 4]

# %%
s1.index = [101,102,103,104,105]
s1
# Out:
# 101    10
# 102    20
# 103    30
# 104    40
# 105    50
# dtype: int64

# %%
s1.index = ['A','B','C','D','E']
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
s1.index = range(1005,1010)
s1
# Out:
# 1005    10
# 1006    20
# 1007    30
# 1008    40
# 1009    50
# dtype: int64

# %%
s1.index = ['A','B','C','D','E']
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# ## ACCESSING DATA IN SERIES

# %%
s1[0]
# Out:
# C:\Users\roder\AppData\Local\Temp\ipykernel_15632\643609873.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# np.int64(10)

# %%
s1['A']
# Out:
# np.int64(10)

# %%
s1.iloc[1]                                               #  FOR DEFAULT INDEX ILOC
# Out:
# np.int64(20)

# %%
s1.loc['B']                                              #  FOR DEFINED INDEX LOC
# Out:
# np.int64(20)

# %% [markdown]
# ## ADD, UPDATE AND DELETE OPERATIONS

# %%
s1['F'] = 60
s1
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# dtype: int64

# %%
s1['B'] = 75
s1
# Out:
# A    10
# B    75
# C    30
# D    40
# E    50
# F    60
# dtype: int64

# %%
s1.drop('E')
# Out:
# A    10
# B    75
# C    30
# D    40
# F    60
# dtype: int64

# %%
s1
# Out:
# A    10
# B    75
# C    30
# D    40
# E    50
# F    60
# dtype: int64

# %%
s2=s1.drop('E')
s2
# Out:
# A    10
# B    75
# C    30
# D    40
# F    60
# dtype: int64

# %%
s1.drop('E',inplace= True)
s1
# Out:
# A    10
# B    75
# C    30
# D    40
# F    60
# dtype: int64

# %% [markdown]
# ## SLICING

# %%
s1[:]
# Out:
# A    10
# B    75
# C    30
# D    40
# F    60
# dtype: int64

# %%
s1[2:4]
# Out:
# C    30
# D    40
# dtype: int64

# %%
s1[::-1]
# Out:
# F    60
# D    40
# C    30
# B    75
# A    10
# dtype: int64

# %% [markdown]
# ## CREATING SERIES DATA FROM A DICTIONARY

# %%
data = { 'Jaipur'     : 'Rajasthan',
         'Mumbai'     : 'Maharashtra',
         'Kolkata'    : 'West Bengal',
         'Chandigarh' : 'Punjab',
         'Patna'      : 'Bihar',
         'Lucknow'    : 'Uttar Pradesh'}

# %%
s2 = pd.Series(data)
s2
# Out:
# Jaipur            Rajasthan
# Mumbai          Maharashtra
# Kolkata         West Bengal
# Chandigarh           Punjab
# Patna                 Bihar
# Lucknow       Uttar Pradesh
# dtype: object

# %%
s2.iloc[1]
# Out:
# 'Maharashtra'

# %%
s2.loc['Mumbai']
# Out:
# 'Maharashtra'

# %%
s2.index
# Out:
# Index(['Jaipur', 'Mumbai', 'Kolkata', 'Chandigarh', 'Patna', 'Lucknow'], dtype='object')

# %%
s2.values
# Out:
# array(['Rajasthan', 'Maharashtra', 'West Bengal', 'Punjab', 'Bihar',
#        'Uttar Pradesh'], dtype=object)

# %%
s2.name = 'States and Capitals'
s2
# Out:
# Jaipur            Rajasthan
# Mumbai          Maharashtra
# Kolkata         West Bengal
# Chandigarh           Punjab
# Patna                 Bihar
# Lucknow       Uttar Pradesh
# Name: States and Capitals, dtype: object

# %%
s2.index.name = 'Capitals'
s2
# Out:
# Capitals
# Jaipur            Rajasthan
# Mumbai          Maharashtra
# Kolkata         West Bengal
# Chandigarh           Punjab
# Patna                 Bihar
# Lucknow       Uttar Pradesh
# Name: States and Capitals, dtype: object

# %%
s2.loc[['Jaipur','Kolkata']]
# Out:
# Capitals
# Jaipur       Rajasthan
# Kolkata    West Bengal
# Name: States and Capitals, dtype: object

# %%
s3 = pd.Series(data=s2, index=['Jaipur','Mumbai','Delhi','Bangaluru','Lucknow'])
s3
# Out:
# Jaipur           Rajasthan
# Mumbai         Maharashtra
# Delhi                  NaN
# Bangaluru              NaN
# Lucknow      Uttar Pradesh
# Name: States and Capitals, dtype: object

# %% [markdown]
# ## FUNCTIONS

# %%
s3.isnull()
# Out:
# Jaipur       False
# Mumbai       False
# Delhi         True
# Bangaluru     True
# Lucknow      False
# Name: States and Capitals, dtype: bool

# %%
s3.isnull().sum()
# Out:
# np.int64(2)

# %%
s3.notnull()
# Out:
# Jaipur        True
# Mumbai        True
# Delhi        False
# Bangaluru    False
# Lucknow       True
# Name: States and Capitals, dtype: bool

# %%
s3.notnull().sum()
# Out:
# np.int64(3)

# %%
s3['Chandigarh'] = 'Punjab'
s3['Kolkata']    = 'West Bengal'
s3['Gandhi Nagar']= 'Gujrat'
s3
# Out:
# Jaipur              Rajasthan
# Mumbai            Maharashtra
# Delhi                     NaN
# Bangaluru                 NaN
# Lucknow         Uttar Pradesh
# Chandigarh             Punjab
# Kolkata           West Bengal
# Gandhi Nagar           Gujrat
# Name: States and Capitals, dtype: object

# %%
s3.head()
# Out:
# Jaipur           Rajasthan
# Mumbai         Maharashtra
# Delhi                  NaN
# Bangaluru              NaN
# Lucknow      Uttar Pradesh
# Name: States and Capitals, dtype: object

# %%
s3.head(3)
# Out:
# Jaipur      Rajasthan
# Mumbai    Maharashtra
# Delhi             NaN
# Name: States and Capitals, dtype: object

# %%
s3.tail()
# Out:
# Bangaluru                 NaN
# Lucknow         Uttar Pradesh
# Chandigarh             Punjab
# Kolkata           West Bengal
# Gandhi Nagar           Gujrat
# Name: States and Capitals, dtype: object

# %%
s3.tail(6)
# Out:
# Delhi                     NaN
# Bangaluru                 NaN
# Lucknow         Uttar Pradesh
# Chandigarh             Punjab
# Kolkata           West Bengal
# Gandhi Nagar           Gujrat
# Name: States and Capitals, dtype: object

# %%
s3['abc'] = 'Punjab'
s3
# Out:
# Jaipur              Rajasthan
# Mumbai            Maharashtra
# Delhi                     NaN
# Bangaluru                 NaN
# Lucknow         Uttar Pradesh
# Chandigarh             Punjab
# Kolkata           West Bengal
# Gandhi Nagar           Gujrat
# abc                    Punjab
# Name: States and Capitals, dtype: object

# %%
s3.duplicated()
# Out:
# Jaipur          False
# Mumbai          False
# Delhi           False
# Bangaluru        True
# Lucknow         False
# Chandigarh      False
# Kolkata         False
# Gandhi Nagar    False
# abc              True
# Name: States and Capitals, dtype: bool

# %%
s3.duplicated().sum()
# Out:
# np.int64(2)

# %%
s3.drop_duplicates()
# Out:
# Jaipur              Rajasthan
# Mumbai            Maharashtra
# Delhi                     NaN
# Lucknow         Uttar Pradesh
# Chandigarh             Punjab
# Kolkata           West Bengal
# Gandhi Nagar           Gujrat
# Name: States and Capitals, dtype: object

# %%
s3.drop_duplicates(inplace= True)

# %%
s3
# Out:
# Jaipur              Rajasthan
# Mumbai            Maharashtra
# Delhi                     NaN
# Lucknow         Uttar Pradesh
# Chandigarh             Punjab
# Kolkata           West Bengal
# Gandhi Nagar           Gujrat
# Name: States and Capitals, dtype: object

# %% [markdown]
# ## DATA FRAMES

# %%
employee1 = pd.Series({'NAME' : 'ANKUR', 'GENDER' : 'MALE', 'SALARY' : 10000})
employee2 = pd.Series({'NAME' : 'SARWAT', 'GENDER' : 'FEMALE', 'SALARY' : 12890000})
employee3 = pd.Series({'NAME' : 'GEETANJALI', 'GENDER' : 'FEMALE', 'SALARY' : 15670000})
employee4 = pd.Series({'NAME' : 'DISHA', 'GENDER' : 'FEMALE', 'SALARY' : 4500000})
employee5 = pd.Series({'NAME' : 'ARCHIT', 'GENDER' : 'MALE', 'SALARY' : 12500000})
employee6 = pd.Series({'NAME' : 'ANIKET', 'GENDER' : 'MALE', 'SALARY' : 2340000})
employee7 = pd.Series({'NAME' : 'TEJASHRI', 'GENDER' : 'FEMALE', 'SALARY' : 76590000})
employee8 = pd.Series({'NAME' : 'ATHARVA', 'GENDER' : 'MALE', 'SALARY' : 34520000})
employee9 = pd.Series({'NAME' : 'VARAD', 'GENDER' : 'MALE', 'SALARY' : 10007800})
employee10 = pd.Series({'NAME' : 'NISHA', 'GENDER' : 'FEMALE', 'SALARY' : 45630000})
employee11 = pd.Series({'NAME' : 'ATHARV', 'GENDER' : 'MALE', 'SALARY' : 78650000})
employee12 = pd.Series({'NAME' : 'SAHIL', 'GENDER' : 'MALE', 'SALARY' : 56740000})
employee13 = pd.Series({'NAME' : 'UTKARSHA', 'GENDER' : 'FEMALE', 'SALARY' : 567410000})
employee14 = pd.Series({'NAME' : 'MIRAL', 'GENDER' : 'FEMALE', 'SALARY' : 456310000})
employee15 = pd.Series({'NAME' : 'VAISHNAVI', 'GENDER' : 'FEMALE', 'SALARY' : 786540000})

# %%
employee = [employee1,employee2,employee3,employee4,employee5,employee6,employee7,employee8,employee9,employee10,employee11,employee12,employee13,employee14,employee15]
df = pd.DataFrame(data = employee,index=range(101,116))
df
# Out:
#            NAME  GENDER     SALARY
# 101       ANKUR    MALE      10000
# 102      SARWAT  FEMALE   12890000
# 103  GEETANJALI  FEMALE   15670000
# 104       DISHA  FEMALE    4500000
# 105      ARCHIT    MALE   12500000
# 106      ANIKET    MALE    2340000
# 107    TEJASHRI  FEMALE   76590000
# 108     ATHARVA    MALE   34520000
# 109       VARAD    MALE   10007800
# 110       NISHA  FEMALE   45630000
# 111      ATHARV    MALE   78650000
# 112       SAHIL    MALE   56740000
# 113    UTKARSHA  FEMALE  567410000
# 114       MIRAL  FEMALE  456310000
# 115   VAISHNAVI  FEMALE  786540000

# %% [markdown]
# ## IMPORTING CSV FILE

# %%
df1 = pd.read_csv('drug200.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df1 = pd.read_csv('drug200.csv')
#       2 df1
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 101 to 115
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    15 non-null     object
#  1   GENDER  15 non-null     object
#  2   SALARY  15 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 492.0+ bytes

# %%
df.head()
# Out:
#            NAME  GENDER    SALARY
# 101       ANKUR    MALE     10000
# 102      SARWAT  FEMALE  12890000
# 103  GEETANJALI  FEMALE  15670000
# 104       DISHA  FEMALE   4500000
# 105      ARCHIT    MALE  12500000

# %%
df.tail()
# Out:
#           NAME  GENDER     SALARY
# 111     ATHARV    MALE   78650000
# 112      SAHIL    MALE   56740000
# 113   UTKARSHA  FEMALE  567410000
# 114      MIRAL  FEMALE  456310000
# 115  VAISHNAVI  FEMALE  786540000

# %%
df.name = 'Employee Details'
df.index.name = 'Employee_Id'

# %%
df.name
# Out:
# 'Employee Details'

# %%
df.columns
# Out:
# Index(['NAME', 'GENDER', 'SALARY'], dtype='object')

# %% [markdown]
# ## ACCESSING DATA FROM DATAFRAME

# %%
df
# Out:
#                    NAME  GENDER     SALARY
# Employee_Id
# 101               ANKUR    MALE      10000
# 102              SARWAT  FEMALE   12890000
# 103          GEETANJALI  FEMALE   15670000
# 104               DISHA  FEMALE    4500000
# 105              ARCHIT    MALE   12500000
# 106              ANIKET    MALE    2340000
# 107            TEJASHRI  FEMALE   76590000
# 108             ATHARVA    MALE   34520000
# 109               VARAD    MALE   10007800
# 110               NISHA  FEMALE   45630000
# 111              ATHARV    MALE   78650000
# 112               SAHIL    MALE   56740000
# 113            UTKARSHA  FEMALE  567410000
# 114               MIRAL  FEMALE  456310000
# 115           VAISHNAVI  FEMALE  786540000

# %%
df['NAME']
# Out:
# Employee_Id
# 101         ANKUR
# 102        SARWAT
# 103    GEETANJALI
# 104         DISHA
# 105        ARCHIT
# 106        ANIKET
# 107      TEJASHRI
# 108       ATHARVA
# 109         VARAD
# 110         NISHA
# 111        ATHARV
# 112         SAHIL
# 113      UTKARSHA
# 114         MIRAL
# 115     VAISHNAVI
# Name: NAME, dtype: object

# %%
df[['NAME']]
# Out:
#                    NAME
# Employee_Id
# 101               ANKUR
# 102              SARWAT
# 103          GEETANJALI
# 104               DISHA
# 105              ARCHIT
# 106              ANIKET
# 107            TEJASHRI
# 108             ATHARVA
# 109               VARAD
# 110               NISHA
# 111              ATHARV
# 112               SAHIL
# 113            UTKARSHA
# 114               MIRAL
# 115           VAISHNAVI

# %%
df[['NAME','SALARY']]
# Out:
#                    NAME     SALARY
# Employee_Id
# 101               ANKUR      10000
# 102              SARWAT   12890000
# 103          GEETANJALI   15670000
# 104               DISHA    4500000
# 105              ARCHIT   12500000
# 106              ANIKET    2340000
# 107            TEJASHRI   76590000
# 108             ATHARVA   34520000
# 109               VARAD   10007800
# 110               NISHA   45630000
# 111              ATHARV   78650000
# 112               SAHIL   56740000
# 113            UTKARSHA  567410000
# 114               MIRAL  456310000
# 115           VAISHNAVI  786540000

# %%
col = ['NAME','SALARY']
df[col]
# Out:
#                    NAME     SALARY
# Employee_Id
# 101               ANKUR      10000
# 102              SARWAT   12890000
# 103          GEETANJALI   15670000
# 104               DISHA    4500000
# 105              ARCHIT   12500000
# 106              ANIKET    2340000
# 107            TEJASHRI   76590000
# 108             ATHARVA   34520000
# 109               VARAD   10007800
# 110               NISHA   45630000
# 111              ATHARV   78650000
# 112               SAHIL   56740000
# 113            UTKARSHA  567410000
# 114               MIRAL  456310000
# 115           VAISHNAVI  786540000

# %%
df.loc[106]
# Out:
# NAME       ANIKET
# GENDER       MALE
# SALARY    2340000
# Name: 106, dtype: object

# %%
df.loc[106]
df.loc[[106]]
# Out:
#                NAME GENDER   SALARY
# Employee_Id
# 106          ANIKET   MALE  2340000

# %%
df.iloc[5]
# Out:
# NAME       ANIKET
# GENDER       MALE
# SALARY    2340000
# Name: 106, dtype: object

# %%
df.iloc[[5]]
# Out:
#                NAME GENDER   SALARY
# Employee_Id
# 106          ANIKET   MALE  2340000

# %%
df.loc[[101,104,105,106,111]]
# Out:
#                NAME  GENDER    SALARY
# Employee_Id
# 101           ANKUR    MALE     10000
# 104           DISHA  FEMALE   4500000
# 105          ARCHIT    MALE  12500000
# 106          ANIKET    MALE   2340000
# 111          ATHARV    MALE  78650000

# %% [markdown]
# ## ACCESSING SPECIFIC VALUES

# %%
df
# Out:
#                    NAME  GENDER     SALARY
# Employee_Id
# 101               ANKUR    MALE      10000
# 102              SARWAT  FEMALE   12890000
# 103          GEETANJALI  FEMALE   15670000
# 104               DISHA  FEMALE    4500000
# 105              ARCHIT    MALE   12500000
# 106              ANIKET    MALE    2340000
# 107            TEJASHRI  FEMALE   76590000
# 108             ATHARVA    MALE   34520000
# 109               VARAD    MALE   10007800
# 110               NISHA  FEMALE   45630000
# 111              ATHARV    MALE   78650000
# 112               SAHIL    MALE   56740000
# 113            UTKARSHA  FEMALE  567410000
# 114               MIRAL  FEMALE  456310000
# 115           VAISHNAVI  FEMALE  786540000

# %%
df.loc[108]['NAME']
# Out:
# 'ATHARVA'

# %%
df.iloc[7]['NAME']
# Out:
# 'ATHARVA'

# %%
df['NAME'][108]
# Out:
# 'ATHARVA'

# %%
df['NAME'][7]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 7 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df['NAME'][7]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# ...

# %%
df.loc[108,'NAME']
# Out:
# 'ATHARVA'

# %%
df.loc[[102,104,108,112]][['NAME']]
# Out:
#                 NAME
# Employee_Id
# 102           SARWAT
# 104            DISHA
# 108          ATHARVA
# 112            SAHIL

# %%
df.loc[102::2]
# Out:
#                 NAME  GENDER     SALARY
# Employee_Id
# 102           SARWAT  FEMALE   12890000
# 104            DISHA  FEMALE    4500000
# 106           ANIKET    MALE    2340000
# 108          ATHARVA    MALE   34520000
# 110            NISHA  FEMALE   45630000
# 112            SAHIL    MALE   56740000
# 114            MIRAL  FEMALE  456310000

# %% [markdown]
# ## ADDING AND DELETING ROWS AND COLUMNS

# %%
df
# Out:
#                    NAME  GENDER     SALARY
# Employee_Id
# 101               ANKUR    MALE      10000
# 102              SARWAT  FEMALE   12890000
# 103          GEETANJALI  FEMALE   15670000
# 104               DISHA  FEMALE    4500000
# 105              ARCHIT    MALE   12500000
# 106              ANIKET    MALE    2340000
# 107            TEJASHRI  FEMALE   76590000
# 108             ATHARVA    MALE   34520000
# 109               VARAD    MALE   10007800
# 110               NISHA  FEMALE   45630000
# 111              ATHARV    MALE   78650000
# 112               SAHIL    MALE   56740000
# 113            UTKARSHA  FEMALE  567410000
# 114               MIRAL  FEMALE  456310000
# 115           VAISHNAVI  FEMALE  786540000

# %%
df.loc[116] = ['ETHANS','MALE',100]
df
# Out:
#                    NAME  GENDER     SALARY
# Employee_Id
# 101               ANKUR    MALE      10000
# 102              SARWAT  FEMALE   12890000
# 103          GEETANJALI  FEMALE   15670000
# 104               DISHA  FEMALE    4500000
# 105              ARCHIT    MALE   12500000
# 106              ANIKET    MALE    2340000
# 107            TEJASHRI  FEMALE   76590000
# 108             ATHARVA    MALE   34520000
# 109               VARAD    MALE   10007800
# 110               NISHA  FEMALE   45630000
# 111              ATHARV    MALE   78650000
# 112               SAHIL    MALE   56740000
# 113            UTKARSHA  FEMALE  567410000
# 114               MIRAL  FEMALE  456310000
# 115           VAISHNAVI  FEMALE  786540000
# 116              ETHANS    MALE        100

# %%
df['AGE'] = 30
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   30
# 102              SARWAT  FEMALE   12890000   30
# 103          GEETANJALI  FEMALE   15670000   30
# 104               DISHA  FEMALE    4500000   30
# 105              ARCHIT    MALE   12500000   30
# 106              ANIKET    MALE    2340000   30
# 107            TEJASHRI  FEMALE   76590000   30
# 108             ATHARVA    MALE   34520000   30
# 109               VARAD    MALE   10007800   30
# 110               NISHA  FEMALE   45630000   30
# 111              ATHARV    MALE   78650000   30
# 112               SAHIL    MALE   56740000   30
# 113            UTKARSHA  FEMALE  567410000   30
# 114               MIRAL  FEMALE  456310000   30
# 115           VAISHNAVI  FEMALE  786540000   30
# 116              ETHANS    MALE        100   30

# %%
df['AGE']= np.random.randint(23,55,16)
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26
# 116              ETHANS    MALE        100   33

# %%
df['CITY'] = 'PUNE'
df
# Out:
#                    NAME  GENDER     SALARY  AGE  CITY
# Employee_Id
# 101               ANKUR    MALE      10000   23  PUNE
# 102              SARWAT  FEMALE   12890000   52  PUNE
# 103          GEETANJALI  FEMALE   15670000   37  PUNE
# 104               DISHA  FEMALE    4500000   40  PUNE
# 105              ARCHIT    MALE   12500000   31  PUNE
# 106              ANIKET    MALE    2340000   24  PUNE
# 107            TEJASHRI  FEMALE   76590000   47  PUNE
# 108             ATHARVA    MALE   34520000   29  PUNE
# 109               VARAD    MALE   10007800   27  PUNE
# 110               NISHA  FEMALE   45630000   33  PUNE
# 111              ATHARV    MALE   78650000   24  PUNE
# 112               SAHIL    MALE   56740000   35  PUNE
# 113            UTKARSHA  FEMALE  567410000   45  PUNE
# 114               MIRAL  FEMALE  456310000   51  PUNE
# 115           VAISHNAVI  FEMALE  786540000   26  PUNE
# 116              ETHANS    MALE        100   33  PUNE

# %%
df.drop('CITY',axis = 1,inplace = True)
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26
# 116              ETHANS    MALE        100   33

# %%
df.drop(116,axis=0,inplace=True)
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26

# %%
name = input('Enter your name :')
gender = input('Enter your gender :')
salary = int(input('Enter your salary :'))
age = int(input('Enter your age :'))

df.loc[116] = [name,gender,salary,age]
df
# Out:
# Enter your name : RAKHI
# Enter your gender : FEMALE
# Enter your salary : 50000
# Enter your age : 23
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26
# 116               RAKHI  FEMALE      50000   23

# %%
df.loc[116,'SALARY'] = 100
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26
# 116               RAKHI  FEMALE        100   23

# %% [markdown]
# ## ACCESSING DATA BASED ON CONDITIONS

# %%
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26
# 116               RAKHI  FEMALE        100   23

# %%
df[df.AGE>40]
# Out:
#                  NAME  GENDER     SALARY  AGE
# Employee_Id
# 102            SARWAT  FEMALE   12890000   52
# 107          TEJASHRI  FEMALE   76590000   47
# 113          UTKARSHA  FEMALE  567410000   45
# 114             MIRAL  FEMALE  456310000   51

# %%
df[df.AGE>40][['NAME','SALARY']]
# Out:
#                  NAME     SALARY
# Employee_Id
# 102            SARWAT   12890000
# 107          TEJASHRI   76590000
# 113          UTKARSHA  567410000
# 114             MIRAL  456310000

# %%
df[df.NAME=='ANKUR']
# Out:
#               NAME GENDER  SALARY  AGE
# Employee_Id
# 101          ANKUR   MALE   10000   23

# %%
df[df.GENDER=='MALE']
# Out:
#                 NAME GENDER    SALARY  AGE
# Employee_Id
# 101            ANKUR   MALE     10000   23
# 105           ARCHIT   MALE  12500000   31
# 106           ANIKET   MALE   2340000   24
# 108          ATHARVA   MALE  34520000   29
# 109            VARAD   MALE  10007800   27
# 111           ATHARV   MALE  78650000   24
# 112            SAHIL   MALE  56740000   35

# %%
df[df.GENDER=='MALE'][df.SALARY>10000000]
# Out:
# C:\Users\roder\AppData\Local\Temp\ipykernel_15632\4230783272.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.GENDER=='MALE'][df.SALARY>10000000]
#                 NAME GENDER    SALARY  AGE
# Employee_Id
# 105           ARCHIT   MALE  12500000   31
# 108          ATHARVA   MALE  34520000   29
# 109            VARAD   MALE  10007800   27
# 111           ATHARV   MALE  78650000   24
# 112            SAHIL   MALE  56740000   35

# %%
df[df.GENDER=='MALE'][df.SALARY>10000000][df.AGE>32]
# Out:
# C:\Users\roder\AppData\Local\Temp\ipykernel_15632\359524044.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.GENDER=='MALE'][df.SALARY>10000000][df.AGE>32]
# C:\Users\roder\AppData\Local\Temp\ipykernel_15632\359524044.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.GENDER=='MALE'][df.SALARY>10000000][df.AGE>32]
#               NAME GENDER    SALARY  AGE
# Employee_Id
# 112          SAHIL   MALE  56740000   35

# %% [markdown]
# ## IMPORTANT FUNCTIONS

# %%
df
# Out:
#                    NAME  GENDER     SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000   23
# 102              SARWAT  FEMALE   12890000   52
# 103          GEETANJALI  FEMALE   15670000   37
# 104               DISHA  FEMALE    4500000   40
# 105              ARCHIT    MALE   12500000   31
# 106              ANIKET    MALE    2340000   24
# 107            TEJASHRI  FEMALE   76590000   47
# 108             ATHARVA    MALE   34520000   29
# 109               VARAD    MALE   10007800   27
# 110               NISHA  FEMALE   45630000   33
# 111              ATHARV    MALE   78650000   24
# 112               SAHIL    MALE   56740000   35
# 113            UTKARSHA  FEMALE  567410000   45
# 114               MIRAL  FEMALE  456310000   51
# 115           VAISHNAVI  FEMALE  786540000   26
# 116               RAKHI  FEMALE        100   23

# %%
df.loc[117] = df.loc[111]
df.loc[118] = df.loc[114]

df.loc[119] = ['Ankush','Male',np.nan,45]
df.loc[120] = ['Krishna','Male',np.nan,45]

df
# Out:
#                    NAME  GENDER       SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000.0   23
# 102              SARWAT  FEMALE   12890000.0   52
# 103          GEETANJALI  FEMALE   15670000.0   37
# 104               DISHA  FEMALE    4500000.0   40
# 105              ARCHIT    MALE   12500000.0   31
# 106              ANIKET    MALE    2340000.0   24
# 107            TEJASHRI  FEMALE   76590000.0   47
# 108             ATHARVA    MALE   34520000.0   29
# 109               VARAD    MALE   10007800.0   27
# 110               NISHA  FEMALE   45630000.0   33
# 111              ATHARV    MALE   78650000.0   24
# 112               SAHIL    MALE   56740000.0   35
# 113            UTKARSHA  FEMALE  567410000.0   45
# 114               MIRAL  FEMALE  456310000.0   51
# 115           VAISHNAVI  FEMALE  786540000.0   26
# 116               RAKHI  FEMALE        100.0   23
# 117              ATHARV    MALE   78650000.0   24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 101 to 120
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    20 non-null     object
#  1   GENDER  20 non-null     object
#  2   SALARY  18 non-null     float64
#  3   AGE     20 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 800.0+ bytes

# %%
df.head()
# Out:
#                    NAME  GENDER      SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE     10000.0   23
# 102              SARWAT  FEMALE  12890000.0   52
# 103          GEETANJALI  FEMALE  15670000.0   37
# 104               DISHA  FEMALE   4500000.0   40
# 105              ARCHIT    MALE  12500000.0   31

# %%
df.tail()
# Out:
#                 NAME  GENDER       SALARY  AGE
# Employee_Id
# 116            RAKHI  FEMALE        100.0   23
# 117           ATHARV    MALE   78650000.0   24
# 118            MIRAL  FEMALE  456310000.0   51
# 119           Ankush    Male          NaN   45
# 120          Krishna    Male          NaN   45

# %%
df.isnull().sum()
# Out:
# NAME      0
# GENDER    0
# SALARY    2
# AGE       0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# NAME      20
# GENDER    20
# SALARY    18
# AGE       20
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.nunique()
# Out:
# NAME      18
# GENDER     3
# SALARY    16
# AGE       14
# dtype: int64

# %%
df.NAME.unique()
# Out:
# array(['ANKUR', 'SARWAT', 'GEETANJALI', 'DISHA', 'ARCHIT', 'ANIKET',
#        'TEJASHRI', 'ATHARVA', 'VARAD', 'NISHA', 'ATHARV', 'SAHIL',
#        'UTKARSHA', 'MIRAL', 'VAISHNAVI', 'RAKHI', 'Ankush', 'Krishna'],
#       dtype=object)

# %%
df.GENDER.unique()
# Out:
# array(['MALE', 'FEMALE', 'Male'], dtype=object)

# %%
df.sort_values(by = 'NAME')
# Out:
#                    NAME  GENDER       SALARY  AGE
# Employee_Id
# 106              ANIKET    MALE    2340000.0   24
# 101               ANKUR    MALE      10000.0   23
# 105              ARCHIT    MALE   12500000.0   31
# 117              ATHARV    MALE   78650000.0   24
# 111              ATHARV    MALE   78650000.0   24
# 108             ATHARVA    MALE   34520000.0   29
# 119              Ankush    Male          NaN   45
# 104               DISHA  FEMALE    4500000.0   40
# 103          GEETANJALI  FEMALE   15670000.0   37
# 120             Krishna    Male          NaN   45
# 114               MIRAL  FEMALE  456310000.0   51
# 118               MIRAL  FEMALE  456310000.0   51
# 110               NISHA  FEMALE   45630000.0   33
# 116               RAKHI  FEMALE        100.0   23
# 112               SAHIL    MALE   56740000.0   35
# 102              SARWAT  FEMALE   12890000.0   52
# 107            TEJASHRI  FEMALE   76590000.0   47
# ...

# %%
df.sort_values(by = 'NAME',ascending= False)
# Out:
#                    NAME  GENDER       SALARY  AGE
# Employee_Id
# 109               VARAD    MALE   10007800.0   27
# 115           VAISHNAVI  FEMALE  786540000.0   26
# 113            UTKARSHA  FEMALE  567410000.0   45
# 107            TEJASHRI  FEMALE   76590000.0   47
# 102              SARWAT  FEMALE   12890000.0   52
# 112               SAHIL    MALE   56740000.0   35
# 116               RAKHI  FEMALE        100.0   23
# 110               NISHA  FEMALE   45630000.0   33
# 118               MIRAL  FEMALE  456310000.0   51
# 114               MIRAL  FEMALE  456310000.0   51
# 120             Krishna    Male          NaN   45
# 103          GEETANJALI  FEMALE   15670000.0   37
# 104               DISHA  FEMALE    4500000.0   40
# 119              Ankush    Male          NaN   45
# 108             ATHARVA    MALE   34520000.0   29
# 117              ATHARV    MALE   78650000.0   24
# 111              ATHARV    MALE   78650000.0   24
# ...

# %%
pd.concat([df,df],axis=1)
# Out:
#                    NAME  GENDER       SALARY  AGE        NAME  GENDER  \
# Employee_Id
# 101               ANKUR    MALE      10000.0   23       ANKUR    MALE
# 102              SARWAT  FEMALE   12890000.0   52      SARWAT  FEMALE
# 103          GEETANJALI  FEMALE   15670000.0   37  GEETANJALI  FEMALE
# 104               DISHA  FEMALE    4500000.0   40       DISHA  FEMALE
# 105              ARCHIT    MALE   12500000.0   31      ARCHIT    MALE
# 106              ANIKET    MALE    2340000.0   24      ANIKET    MALE
# 107            TEJASHRI  FEMALE   76590000.0   47    TEJASHRI  FEMALE
# 108             ATHARVA    MALE   34520000.0   29     ATHARVA    MALE
# 109               VARAD    MALE   10007800.0   27       VARAD    MALE
# 110               NISHA  FEMALE   45630000.0   33       NISHA  FEMALE
# 111              ATHARV    MALE   78650000.0   24      ATHARV    MALE
# 112               SAHIL    MALE   56740000.0   35       SAHIL    MALE
# ...

# %%
pd.concat([df,df],axis=0)
# Out:
#                    NAME  GENDER       SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000.0   23
# 102              SARWAT  FEMALE   12890000.0   52
# 103          GEETANJALI  FEMALE   15670000.0   37
# 104               DISHA  FEMALE    4500000.0   40
# 105              ARCHIT    MALE   12500000.0   31
# 106              ANIKET    MALE    2340000.0   24
# 107            TEJASHRI  FEMALE   76590000.0   47
# 108             ATHARVA    MALE   34520000.0   29
# 109               VARAD    MALE   10007800.0   27
# 110               NISHA  FEMALE   45630000.0   33
# 111              ATHARV    MALE   78650000.0   24
# 112               SAHIL    MALE   56740000.0   35
# 113            UTKARSHA  FEMALE  567410000.0   45
# 114               MIRAL  FEMALE  456310000.0   51
# 115           VAISHNAVI  FEMALE  786540000.0   26
# 116               RAKHI  FEMALE        100.0   23
# 117              ATHARV    MALE   78650000.0   24
# ...

# %%
df.GENDER.value_counts()
# Out:
# GENDER
# FEMALE    10
# MALE       8
# Male       2
# Name: count, dtype: int64

# %%
df.count()
# Out:
# NAME      20
# GENDER    20
# SALARY    18
# AGE       20
# dtype: int64

# %%
df.describe()
# Out:
#              SALARY        AGE
# count  1.800000e+01  20.000000
# mean   1.497371e+08  35.600000
# std    2.399608e+08  10.560104
# min    1.000000e+02  23.000000
# 25%    1.063085e+07  25.500000
# 50%    4.007500e+07  34.000000
# 75%    7.865000e+07  45.000000
# max    7.865400e+08  52.000000

# %%
df.AGE.mean()
# Out:
# np.float64(35.6)

# %%
df
# Out:
#                    NAME  GENDER       SALARY  AGE
# Employee_Id
# 101               ANKUR    MALE      10000.0   23
# 102              SARWAT  FEMALE   12890000.0   52
# 103          GEETANJALI  FEMALE   15670000.0   37
# 104               DISHA  FEMALE    4500000.0   40
# 105              ARCHIT    MALE   12500000.0   31
# 106              ANIKET    MALE    2340000.0   24
# 107            TEJASHRI  FEMALE   76590000.0   47
# 108             ATHARVA    MALE   34520000.0   29
# 109               VARAD    MALE   10007800.0   27
# 110               NISHA  FEMALE   45630000.0   33
# 111              ATHARV    MALE   78650000.0   24
# 112               SAHIL    MALE   56740000.0   35
# 113            UTKARSHA  FEMALE  567410000.0   45
# 114               MIRAL  FEMALE  456310000.0   51
# 115           VAISHNAVI  FEMALE  786540000.0   26
# 116               RAKHI  FEMALE        100.0   23
# 117              ATHARV    MALE   78650000.0   24
# ...

# %%
df.SALARY.mean()
# Out:
# np.float64(149737105.55555555)

# %%
df.groupby(by='GENDER')['AGE'].mean()
# Out:
# GENDER
# FEMALE    40.500
# MALE      27.125
# Male      45.000
# Name: AGE, dtype: float64

# %%
df.groupby(by='GENDER')['SALARY'].mean()
# Out:
# GENDER
# FEMALE    242185010.0
# MALE       34177225.0
# Male              NaN
# Name: SALARY, dtype: float64

# %%
df['CITY'] = ['PUNE','MUMBAI','NAGPUR','DELHI','PUNE','MUMBAI','NAGPUR','DELHI','PUNE','MUMBAI','NAGPUR','DELHI','PUNE','MUMBAI','NAGPUR','DELHI','PUNE','MUMBAI','NAGPUR','DELHI']
df
# Out:
#                    NAME  GENDER       SALARY  AGE    CITY
# Employee_Id
# 101               ANKUR    MALE      10000.0   23    PUNE
# 102              SARWAT  FEMALE   12890000.0   52  MUMBAI
# 103          GEETANJALI  FEMALE   15670000.0   37  NAGPUR
# 104               DISHA  FEMALE    4500000.0   40   DELHI
# 105              ARCHIT    MALE   12500000.0   31    PUNE
# 106              ANIKET    MALE    2340000.0   24  MUMBAI
# 107            TEJASHRI  FEMALE   76590000.0   47  NAGPUR
# 108             ATHARVA    MALE   34520000.0   29   DELHI
# 109               VARAD    MALE   10007800.0   27    PUNE
# 110               NISHA  FEMALE   45630000.0   33  MUMBAI
# 111              ATHARV    MALE   78650000.0   24  NAGPUR
# 112               SAHIL    MALE   56740000.0   35   DELHI
# 113            UTKARSHA  FEMALE  567410000.0   45    PUNE
# 114               MIRAL  FEMALE  456310000.0   51  MUMBAI
# 115           VAISHNAVI  FEMALE  786540000.0   26  NAGPUR
# ...

# %%
df.groupby(by=['CITY','GENDER'])['SALARY'].mean()
# Out:
# CITY    GENDER
# DELHI   FEMALE    2.250050e+06
#         MALE      4.563000e+07
#         Male               NaN
# MUMBAI  FEMALE    2.427850e+08
#         MALE      2.340000e+06
# NAGPUR  FEMALE    2.929333e+08
#         MALE      7.865000e+07
#         Male               NaN
# PUNE    FEMALE    5.674100e+08
#         MALE      2.529195e+07
# Name: SALARY, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.SALARY.mean()
# Out:
# np.float64(131703405.88235295)

# %%
df.SALARY.replace(np.nan,df.SALARY.mean())
# Out:
# Employee_Id
# 101    1.000000e+04
# 102    1.289000e+07
# 103    1.567000e+07
# 104    4.500000e+06
# 105    1.250000e+07
# 106    2.340000e+06
# 107    7.659000e+07
# 108    3.452000e+07
# 109    1.000780e+07
# 110    4.563000e+07
# 111    7.865000e+07
# 112    5.674000e+07
# 113    5.674100e+08
# 114    4.563100e+08
# 115    7.865400e+08
# 116    1.000000e+02
# 117    7.865000e+07
# 119    1.317034e+08
# 120    1.317034e+08
# Name: SALARY, dtype: float64

# %%
df
# Out:
#                    NAME  GENDER       SALARY  AGE    CITY
# Employee_Id
# 101               ANKUR    MALE      10000.0   23    PUNE
# 102              SARWAT  FEMALE   12890000.0   52  MUMBAI
# 103          GEETANJALI  FEMALE   15670000.0   37  NAGPUR
# 104               DISHA  FEMALE    4500000.0   40   DELHI
# 105              ARCHIT    MALE   12500000.0   31    PUNE
# 106              ANIKET    MALE    2340000.0   24  MUMBAI
# 107            TEJASHRI  FEMALE   76590000.0   47  NAGPUR
# 108             ATHARVA    MALE   34520000.0   29   DELHI
# 109               VARAD    MALE   10007800.0   27    PUNE
# 110               NISHA  FEMALE   45630000.0   33  MUMBAI
# 111              ATHARV    MALE   78650000.0   24  NAGPUR
# 112               SAHIL    MALE   56740000.0   35   DELHI
# 113            UTKARSHA  FEMALE  567410000.0   45    PUNE
# 114               MIRAL  FEMALE  456310000.0   51  MUMBAI
# 115           VAISHNAVI  FEMALE  786540000.0   26  NAGPUR
# ...

# %%
df.SALARY.replace(np.nan,df.SALARY.mean(),inplace = True)
df
# Out:
# C:\Users\roder\AppData\Local\Temp\ipykernel_15632\1203343733.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.SALARY.replace(np.nan,df.SALARY.mean(),inplace = True)
#                    NAME  GENDER        SALARY  AGE    CITY
# Employee_Id
# 101               ANKUR    MALE  1.000000e+04   23    PUNE
# 102              SARWAT  FEMALE  1.289000e+07   52  MUMBAI
# 103          GEETANJALI  FEMALE  1.567000e+07   37  NAGPUR
# 104               DISHA  FEMALE  4.500000e+06   40   DELHI
# ...
