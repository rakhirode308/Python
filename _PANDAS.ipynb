# %%
# How to READ DATA

# CSV File
import pandas as pd
#read data from CSV File into a dataframe
df = pd.read_csv("Automobile_data.csv")
print(df)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# ENCODING is a process of converting text into a format that computers can store and read.
# utf-8 or latin1 are encoding examples.

import pandas as pd
#read data from CSV File into a dataframe
df = pd.read_csv("Automobile_data.csv",encoding="utf-8")
print(df)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import pandas as pd
#read data from CSV File into a dataframe
df = pd.read_csv("Automobile_data.csv",encoding="latin1")
print(df)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# Excel File
import pandas as pd
df = pd.read_excel("SGGS_Online Test Result.xlsx")
print(df)
# Out:
#     Unnamed: 0 Unnamed: 1             Unnamed: 2             Unnamed: 3
# 0          NaN      Sr.No              Full Name                  Email
# 1          NaN          1         Vaibhav ingole  2023bit510@sggs.ac.in
# 2          NaN          2          Rutwik Jadhav  2022bcs154@sggs.ac.in
# 3          NaN          3      Venkatesh Bogewar  2022bcs052@sggs.ac.in
# 4          NaN          4       Vaishnavi Pohare  2022bcs034@sggs.ac.in
# 5          NaN          5          Anushka Pande  2022bit042@sggs.ac.in
# 6          NaN          6        Harshal Mahajan  2022bcs107@sggs.ac.in
# 7          NaN          7  sanjyotsingh wasrikar  2022bcs129@sggs.ac.in
# 8          NaN          8         Shruti Meshram  2022bcs084@sggs.ac.in
# 9          NaN          9           Suyash  Tupe  2022bcs086@sggs.ac.in
# 10         NaN         10          Pratik Parhad  2022bit152@sggs.ac.in
# 11         NaN         11           Gauri Tarale  2023bcs508@sggs.ac.in
# ...

# %%
#JSON File
import pandas as pd
df = pd.read_json("sample_data.json")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 #JSON File
#       2 import pandas as pd
# ----> 3 df = pd.read_json("sample_data.json")
#       4 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
# ...

# %%
# data stored at google cloud storage platform use gcsfs library to read data

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi

# %%
# How to Save data

import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)

df.to_csv('output.csv')
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)

df.to_csv('output.csv', index=False)
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)

df.to_excel('output.xlsx', index=False)
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)

df.to_json('output.json', index=False)
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi

# %%
# Explore Data
1. Understand the Data set.(rows,columns,type of data in text,no.s or dates)
2. identify the problems.(missing data find,incorrect data,duplicate entries)
3. Plan next steps.

# %%
#head(n): by default starting 5 rows
#tail(n): by default last 5 rows

import pandas as pd
df = pd.read_csv('Automobile_data.csv')
print('Display first ten rows\n',df.head(10))
print('Display last ten rows\n',df.tail(10))
# Out:
# Display first ten rows
#     symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
#head(n): by default starting 5 rows
#tail(n): by default last 5 rows

import pandas as pd
df = pd.read_csv('Automobile_data.csv')
print('Display first ten rows\n',df.head())
print('Display last ten rows\n',df.tail())
# Out:
# Display first ten rows
#     symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Problem why to understand data:
1. rows, columns in data?
2. what type of data?
3. missing data?

# info() method gives concise summary of your dataframe.
1.number of rows and columns
2.column name
3.datatypes (int64, float64, object)
4.non null counts(missing data in column)
5.memory usage of the dataframe

# %%
import pandas as pd
df = pd.read_csv('Automobile_data.csv')
print('displaying info of dataset')
print(df.info())
# Out:
# displaying info of dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
# ...

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam'],
    'Age':[10,20,30],
    'City':['Nagpur','Mumbai','Delhi']
}

df = pd.DataFrame(data)
print(df)

print('\nDisplaying the info of data set\n')
print(df.info())
# Out:
#         Name  Age    City
# 0        Ram   10  Nagpur
# 1      Shyam   20  Mumbai
# 2  Ghanshyam   30   Delhi
#
# Displaying the info of data set
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
# Describe Method: summary of descriptive statistics for numerical columns in dataframe.

#step1: sample data frame

import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}
df = pd.DataFrame(data)
print('Sample Dataframe')
print(df)
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}
df = pd.DataFrame(data)
print('Sample Dataframe')
print(df)
print('Descriptive Statistics')
print(df.describe())
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# Descriptive Statistics
#              Age        Salary  Performance Score
# count   8.000000      8.000000           8.000000
# mean   30.000000  54000.000000          87.125000
# std     5.529144   8194.074514           5.817154
# min    22.000000  45000.000000          78.000000
# 25%    27.250000  48750.000000          83.750000
# 50%    29.500000  51000.000000          88.500000
# 75%    32.500000  58500.000000          90.500000
# max    40.000000  70000.000000          95.000000

# %%
'''
1. count- number of non null/non missing values in each column.
2. mean- Arithmetic Average of values in each column.
3. std/standard deviation-  tells us how much the values in a column are spread out or different from the mean/average.
   a.Small std- Values very close to std.[48,49,50*,51,52]
   b.Large std- Values very far from mean/average.[10,20,30*,40,50]
4.min- minimum value in column data.
5. 25% - first quartile, average of first minimum values of column data,arranged in ascending order.
6. 50% - average of middle values of column data arranged in ascending order.
7.75% - average of last values of column data arranged in ascending order.
8.max - highest value in column data.
'''

# %%
# Before Analysing or Manipulating your dataset:
'''
1. How Big is your dataset?(how many rows, columns in it)
2. What are the Names of the Columns?

# Pandas provide two Attributes to solve above problems:-
 Shapes and Columns.
 1.Shapes - Will return a tuple of Number of Rows and Number of Columns.
 2.Columns - Return name of column as an index object.
'''

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}
df = pd.DataFrame(data)
print(df)
print(f'Shape: {df.shape}')
print(f'Column Names: {df.columns}')
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# Shape: (8, 4)
# Column Names: Index(['Name', 'Age', 'Salary', 'Performance Score'], dtype='object')

# %%
  1- Select specific column
  2- Filter Rows
  3- Combine Multiple Conditions

1- Square Brackets
2- Boolean Conditions

* Selecting Columns:
   1- A Series- returns single column
   2- Dataframe- multiple columns of data


   column = df["column name"]
   subset = df["column1","column2","..."]
 
* Filtering Rows:
    Boolean Indexing

    # based on a single condition:
    filtered_Rows = df[df['Salary']>50000]
    # combine multiple conditions
    filtered_Rows = df[(df['Column1']>Value1) & (df['Column2']<80000)]

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

#display the dataframe
print("Sample Dataframe")
print(df)
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

#display the dataframe
print("Sample Dataframe")
print(df)
print("Name(Single column return series)")
print(df['Name'])
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# Name(Single column return series)
# 0          Ram
# 1        Shyam
# 2    Ghanshyam
# 3    Dhanshyam
# 4        Aditi
# 5      Jagdish
# 6          Raj
# 7       Simran
# Name: Name, dtype: object

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

#display the dataframe
print("Sample Dataframe")
print(df)
print("Name(Single column return series)")
name = df['Name']
print(name)
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# Name(Single column return series)
# 0          Ram
# 1        Shyam
# 2    Ghanshyam
# 3    Dhanshyam
# 4        Aditi
# 5      Jagdish
# 6          Raj
# 7       Simran
# Name: Name, dtype: object

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

#display the dataframe
print("Sample Dataframe")
print(df)
print("Name(Single column return series)")
name = df['Name']
print(name)
#selecting multiple columns
subset = df[['Name','Salary']]
print('\nSubset with Name and Salary')
print(subset)
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# Name(Single column return series)
# 0          Ram
# 1        Shyam
# 2    Ghanshyam
# 3    Dhanshyam
# 4        Aditi
# 5      Jagdish
# 6          Raj
# 7       Simran
# Name: Name, dtype: object
#
# Subset with Name and Salary
#         Name  Salary
# 0        Ram   50000
# 1      Shyam   60000
# 2  Ghanshyam   45000
# 3  Dhanshyam   52000
# 4      Aditi   49000
# 5    Jagdish   70000
# 6        Raj   48000
# 7     Simran   58000

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

high_salary = df[df['Salary'] > 50000]
print('Employees with salary > 50000')
print(high_salary)
# Out:
# Employees with salary > 50000
#         Name  Age  Salary  Performance Score
# 1      Shyam   34   60000                 90
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
# 7     Simran   32   58000                 89

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

high_salary = df[df['Salary'] > 50000]
print('Employees with salary > 50000')
print(high_salary)

#filtering rows, salary > 50k & age > 30
filtered = df[(df['Age'] > 30) & (df['Salary'] > 50000)]
print(f'Employee list Age > 30 + Salary > 50000')
print(filtered)
# Out:
# Employees with salary > 50000
#         Name  Age  Salary  Performance Score
# 1      Shyam   34   60000                 90
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
# 7     Simran   32   58000                 89
# Employee list Age > 30 + Salary > 50000
#       Name  Age  Salary  Performance Score
# 1    Shyam   34   60000                 90
# 5  Jagdish   40   70000                 95
# 7   Simran   32   58000                 89

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

high_salary = df[df['Salary'] > 50000]
print('Employees with salary > 50000')
print(high_salary)

#filtering rows, salary > 50k & age > 30
filtered = df[(df['Age'] > 30) & (df['Salary'] > 50000)]
print(f'Employee list Age > 30 + Salary > 50000')
print(filtered)

# using OR condition
filtered_or = df[(df['Age'] > 35) | (df['Performance Score'] > 90)]
print('Employees older than 35 OR performance score > 90')
print(filtered_or)
# Out:
# Employees with salary > 50000
#         Name  Age  Salary  Performance Score
# 1      Shyam   34   60000                 90
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
# 7     Simran   32   58000                 89
# Employee list Age > 30 + Salary > 50000
#       Name  Age  Salary  Performance Score
# 1    Shyam   34   60000                 90
# 5  Jagdish   40   70000                 95
# 7   Simran   32   58000                 89
# Employees older than 35 OR performance score > 90
#         Name  Age  Salary  Performance Score
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95

# %%
 # Adding Columns: using directly by assignment, using insert method

import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)
# square brackets df['column_name'] = some_Data

df['Bonus'] = df['Salary'] * 0.1
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
#         Name  Age  Salary  Performance Score   Bonus
# 0        Ram   28   50000                 85  5000.0
# 1      Shyam   34   60000                 90  6000.0
# 2  Ghanshyam   22   45000                 78  4500.0
# 3  Dhanshyam   30   52000                 92  5200.0
# 4      Aditi   29   49000                 88  4900.0
# 5    Jagdish   40   70000                 95  7000.0
# 6        Raj   25   48000                 80  4800.0
# 7     Simran   32   58000                 89  5800.0

# %%
 # Adding Columns
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)
# square brackets df['column_name'] = some_Data

df['Bonus'] = df['Salary'] * 0.1
print(df)

#using insert()
# df.insert(location. 'column_name', some_data)
df.insert(0, 'Employee ID', [10,20,30,40,50,60,70,80])
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
#         Name  Age  Salary  Performance Score   Bonus
# 0        Ram   28   50000                 85  5000.0
# 1      Shyam   34   60000                 90  6000.0
# 2  Ghanshyam   22   45000                 78  4500.0
# 3  Dhanshyam   30   52000                 92  5200.0
# 4      Aditi   29   49000                 88  4900.0
# 5    Jagdish   40   70000                 95  7000.0
# 6        Raj   25   48000                 80  4800.0
# 7     Simran   32   58000                 89  5800.0
#    Employee ID       Name  Age  Salary  Performance Score   Bonus
# ...

# %%
# Updating Values: using .loc method, to update bulk/more values combine conditions.
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

# .loc[]
# df.loc[row_index, 'column_name'] = new_value
df.loc[0, 'Salary'] = 55000
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
#         Name  Age  Salary  Performance Score
# 0        Ram   28   55000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89

# %%
# Updating Values
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

# increasing salary by 5%
df['Salary'] = df['Salary'] * 1.05
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
#         Name  Age   Salary  Performance Score
# 0        Ram   28  52500.0                 85
# 1      Shyam   34  63000.0                 90
# 2  Ghanshyam   22  47250.0                 78
# 3  Dhanshyam   30  54600.0                 92
# 4      Aditi   29  51450.0                 88
# 5    Jagdish   40  73500.0                 95
# 6        Raj   25  50400.0                 80
# 7     Simran   32  60900.0                 89

# %%
# Removing Columns:  using drop method
# Updating Values
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,34,22,30,29,40,25,32],
    'Salary':[50000,60000,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

# df.drop(columns = ['column_name'], inplace=True)
print('Modified data')
df.drop(columns = ['Performance Score','Age'], inplace=True)
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# Modified data
#         Name  Salary
# 0        Ram   50000
# 1      Shyam   60000
# 2  Ghanshyam   45000
# 3  Dhanshyam   52000
# 4      Aditi   49000
# 5    Jagdish   70000
# 6        Raj   48000
# 7     Simran   58000

# %%
# Handling missing data
1. NaN - not a number
2. None - (for object datatypes)
3. 
# steps before handling missing data/ to detect missing values
1. isnull(): returns boolean dataframe
            True - NaN value is missing
            False - value is present
# steps to handle missing values
1. dropna(): drop missing values of rows or columns
            df.dropna(axis = 0/1, inplace = True)  #axis=0 means drop rows with missing values
                                                   #axis=1 means drop columns with missing values
                                                   #inplace=True means modifies and returns original datafram

# %%
import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df.isnull())
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
#     Name    Age  Salary  Performance Score
# 0  False  False   False              False
# 1   True   True    True               True
# 2  False  False   False              False
# 3  False  False   False              False
# 4  False  False   False              False
# 5  False  False   False              False
# 6  False  False   False              False
# 7  False  False   False              False

# %%
import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df.isnull().sum())    #returns series of count of number of missing values in column
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# Name                 1
# Age                  1
# Salary               1
# Performance Score    1
# dtype: int64

# %%
import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df.dropna(inplace=True))
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# None
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0

# %%
import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df.dropna(axis=1, inplace=True))
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# None
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df.dropna(axis=0, inplace=True))
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# None
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0

# %%
#fillna(value, inplace=True) : instead of removing values, fill values by default

import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df.fillna(0, inplace=True))
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# None
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1          0   0.0      0.0                0.0
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0

# %%
#fillna(value, inplace=True) : instead of removing values, fill values by default

import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df['Age'].fillna(df['Age'].mean(), inplace=True))
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# None
#         Name        Age   Salary  Performance Score
# 0        Ram  28.000000  50000.0               85.0
# 1       None  29.428571      NaN                NaN
# 2  Ghanshyam  22.000000  45000.0               78.0
# 3  Dhanshyam  30.000000  52000.0               92.0
# 4      Aditi  29.000000  49000.0               88.0
# 5    Jagdish  40.000000  70000.0               95.0
# 6        Raj  25.000000  48000.0               80.0
# 7     Simran  32.000000  58000.0               89.0
# ...

# %%
#fillna(value, inplace=True) : instead of removing values, fill values by default

import pandas as pd
data = {
    'Name':['Ram',None,'Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)

print(df['Age'].fillna(df['Age'].mean(), inplace=True))
print(df['Salary'].fillna(df['Salary'].mean(), inplace=True))
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1       None   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# None
# None
#         Name        Age        Salary  Performance Score
# 0        Ram  28.000000  50000.000000               85.0
# 1       None  29.428571  53142.857143                NaN
# 2  Ghanshyam  22.000000  45000.000000               78.0
# 3  Dhanshyam  30.000000  52000.000000               92.0
# 4      Aditi  29.000000  49000.000000               88.0
# 5    Jagdish  40.000000  70000.000000               95.0
# 6        Raj  25.000000  48000.000000               80.0
# 7     Simran  32.000000  58000.000000               89.0
# ...

# %%
# Interpolation is a technique in which we fill missing values with estimated value.
-Types: linear, polynomial and time interpolation.
- used to preserve data integrity: instead of droping rows or columns,replace missing values with arbitrary numbers.
- smooth trends
-avoid data loss
interpolate(method,axis,inplace=True): used for filling missing values in columns or dataframes.

# %%
import pandas as pd
data = {
    'Name':['Ram','Shyam','Ghanshyam','Dhanshyam','Aditi','Jagdish','Raj','Simran'],
    'Age':[28,None,22,30,29,40,25,32],
    'Salary':[50000,None,45000,52000,49000,70000,48000,58000],
    'Performance Score':[85,None,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)
df.interpolate(method='linear',axis=0,inplace=True)
print(df)
# Out:
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1      Shyam   NaN      NaN                NaN
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
#         Name   Age   Salary  Performance Score
# 0        Ram  28.0  50000.0               85.0
# 1      Shyam  25.0  47500.0               81.5
# 2  Ghanshyam  22.0  45000.0               78.0
# 3  Dhanshyam  30.0  52000.0               92.0
# 4      Aditi  29.0  49000.0               88.0
# 5    Jagdish  40.0  70000.0               95.0
# 6        Raj  25.0  48000.0               80.0
# 7     Simran  32.0  58000.0               89.0
# ...

# %%
import pandas as pd
data = {
    'Time':[1,2,3,4,5],
    'Value':[10,None,30,None,50]
}
df= pd.DataFrame(data)

print('Before interpolation')
print(df)

df['Value']= df['Value'].interpolate(method='linear')
print('After interpolation')
print(df)
# Out:
# Before interpolation
#    Time  Value
# 0     1   10.0
# 1     2    NaN
# 2     3   30.0
# 3     4    NaN
# 4     5   50.0
# After interpolation
#    Time  Value
# 0     1   10.0
# 1     2   20.0
# 2     3   30.0
# 3     4   40.0
# 4     5   50.0

# %%
# use interpolation during Time-Series data, Numeric data with trends,avoid dropping rows

# %%
# SORTING: arranging rows in dataframe based on the values of one or more columns
#Sorting data:-
@SORTING DATA IN 1 COLUMN:  sort_values()
  df.sort_values(by='Column Name', True/False, inplace=True)

# %%
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun'],
    'Age':[28,34,22],
    'Salary':[10000,20000,30000]
}

df = pd.DataFrame(data)
df.sort_values(by='Age', ascending=False, inplace=True)
print('Sorted Age by Descending')
print(df)
# Out:
# Sorted Age by Descending
#     Name  Age  Salary
# 1  Varun   34   20000
# 0   Arun   28   10000
# 2  Karun   22   30000

# %%
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun'],
    'Age':[28,34,22],
    'Salary':[10000,20000,30000]
}

df = pd.DataFrame(data)
df.sort_values(by='Age', ascending=True, inplace=True)
print('Sorted Age by Descending')
print(df)
# Out:
# Sorted Age by Descending
#     Name  Age  Salary
# 2  Karun   22   30000
# 0   Arun   28   10000
# 1  Varun   34   20000

# %%
#df.sort_values(by=['Age','Salary'], ascending=True, inplace=True)
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun'],
    'Age':[28,34,22],
    'Salary':[10000,20000,30000]
}

df = pd.DataFrame(data)
df.sort_values(by=['Age','Salary'], ascending=False, inplace=True)
print('Sorted Age by Descending')
print(df)
# Out:
# Sorted Age by Descending
#     Name  Age  Salary
# 1  Varun   34   20000
# 0   Arun   28   10000
# 2  Karun   22   30000

# %%
#df.sort_values(by=['Age','Salary'], ascending=[True,False], inplace=True)
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun'],
    'Age':[28,34,22],
    'Salary':[10000,20000,30000]
}

df = pd.DataFrame(data)
df.sort_values(by=['Age','Salary'], ascending=[True,False], inplace=True)
print('Sorted Age by Descending')
print(df)
# Out:
# Sorted Age by Descending
#     Name  Age  Salary
# 2  Karun   22   30000
# 0   Arun   28   10000
# 1  Varun   34   20000

# %%
#AGGREGATION: CALCULATING SUMMARY STATISTICS(SUM,MEAN,etc)
#Summary Statistics: Numerical summaries of columns(average,total value,min value,max value)
df['column name'].mean()
df['column name'].sum()
df['column name'].min()
df['column name'].max()

# %%
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun'],
    'Age':[28,34,22],
    'Salary':[10000,20000,30000]
}

df = pd.DataFrame(data)

avg_salary = df['Salary'].mean()
print(avg_salary)
# Out:
# 20000.0

# %%
# GROUPING: Split data into small groups
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun','Narun','Marun'],
    'Age':[28,34,22,34,28],
    'Salary':[50000,60000,45000,52000,48000]
}

df = pd.DataFrame(data)
grouped = df.groupby('Age')['Salary'].sum()
print(grouped)
# Out:
# Age
# 22     45000
# 28     98000
# 34    112000
# Name: Salary, dtype: int64

# %%
# Grouping for multiple columns
import pandas as pd
data = {
    'Name':['Arun','Varun','Karun','Narun','Marun'],
    'Age':[28,34,22,34,28],
    'Salary':[50000,60000,45000,52000,48000]
}

df = pd.DataFrame(data)
grouped = df.groupby(['Name','Age'])['Salary'].sum()
print(grouped)
# Out:
# Name   Age
# Arun   28     50000
# Karun  22     45000
# Marun  28     48000
# Narun  34     52000
# Varun  34     60000
# Name: Salary, dtype: int64

# %%
# Aggregation Functions
1-Sum(): add all values in group
2-Mean(): calculates average value
3-Count(): gives count of non NAN values
4-Min(): gives minimum value of group
5-Max(): gives maximum value 
6-Std(): standard deviation

# %%
# MERGING AND JOINING
#  Combining multiple datasets to give result
# pd.merge(df1,df2,on='Column_Name', how='type of join')

import pandas as pd
#customer dataframe
df_customers = pd.DataFrame({
    'CustomerID':[1,2,3],
    'Name':['Ramesh','Suresh','Kalpesh']
})
#order dataframe
df_orders = pd.DataFrame({
    'CustomerID':[1,2,4],
    'OrderAmount':[250,450,350]
})
#merge
df_merged = pd.merge(df_customers,df_orders, on='CustomerID', how='inner')
print('inner join')
print(df_merged)
# Out:
# inner join
#    CustomerID    Name  OrderAmount
# 0           1  Ramesh          250
# 1           2  Suresh          450

# %%
import pandas as pd
#customer dataframe
df_customers = pd.DataFrame({
    'CustomerID':[1,2,3],
    'Name':['Ramesh','Suresh','Kalpesh']
})
#order dataframe
df_orders = pd.DataFrame({
    'CustomerID':[1,2,4],
    'OrderAmount':[250,450,350]
})
#merge
df_merged = pd.merge(df_customers,df_orders, on='CustomerID', how='outer')
print('outer join')
print(df_merged)
# Out:
# outer join
#    CustomerID     Name  OrderAmount
# 0           1   Ramesh        250.0
# 1           2   Suresh        450.0
# 2           3  Kalpesh          NaN
# 3           4      NaN        350.0

# %%
import pandas as pd
#customer dataframe
df_customers = pd.DataFrame({
    'CustomerID':[1,2,3],
    'Name':['Ramesh','Suresh','Kalpesh']
})
#order dataframe
df_orders = pd.DataFrame({
    'CustomerID':[1,2,4],
    'OrderAmount':[250,450,350]
})
#merge
df_merged = pd.merge(df_customers,df_orders, on='CustomerID', how='left')
print('left join')
print(df_merged)
# Out:
# left join
#    CustomerID     Name  OrderAmount
# 0           1   Ramesh        250.0
# 1           2   Suresh        450.0
# 2           3  Kalpesh          NaN

# %%
import pandas as pd
#customer dataframe
df_customers = pd.DataFrame({
    'CustomerID':[1,2,3],
    'Name':['Ramesh','Suresh','Kalpesh']
})
#order dataframe
df_orders = pd.DataFrame({
    'CustomerID':[1,2,4],
    'OrderAmount':[250,450,350]
})
#merge
df_merged = pd.merge(df_customers,df_orders, on='CustomerID', how='right')
print('right join')
print(df_merged)
# Out:
# right join
#    CustomerID    Name  OrderAmount
# 0           1  Ramesh          250
# 1           2  Suresh          450
# 2           4     NaN          350

# %%
# CROSS JOIN: Cartesian product of two datasets
 '''   1df = m rows
    2df = n rows
    m * n rows
 '''

# %%
# CONCATENATING DATAFRAMES: combine dataframes vertically(rowwise or horizontaly(columnwise
'''
     pd.concate([df1,df2], axis=0, ignore_index=True)
'''
#vertically
import pandas as pd
#region1
df_Region1 = pd.DataFrame({
        'CustomerID':[1,2],
       'Name':['Ramesh','Suresh']
})
#region2
df_Region2 = pd.DataFrame({
        'CustomerID':[3,4],
       'Name':['Babu','Shyam']
})
# concatenate vertically
df_concat = pd.concat([df_Region1, df_Region2], ignore_index=True)
print(df_concat)
# Out:
#    CustomerID    Name
# 0           1  Ramesh
# 1           2  Suresh
# 2           3    Babu
# 3           4   Shyam

# %%
#horizontally
import pandas as pd
#region1
df_Region1 = pd.DataFrame({
        'CustomerID':[1,2],
       'Name':['Ramesh','Suresh']
})
#region2
df_Region2 = pd.DataFrame({
        'CustomerID':[3,4],
       'Name':['Babu','Shyam']
})
# concatenate horizontally
df_concat = pd.concat([df_Region1, df_Region2], axis=1, ignore_index=True)
print(df_concat)
# Out:
#    0       1  2      3
# 0  1  Ramesh  3   Babu
# 1  2  Suresh  4  Shyam

# %%
#vertically
import pandas as pd
#region1
df_Region1 = pd.DataFrame({
        'CustomerID':[1,2],
       'Name':['Ramesh','Suresh']
})
#region2
df_Region2 = pd.DataFrame({
        'CustomerID':[3,4],
       'Name':['Babu','Shyam']
})
# concatenate vertically
df_concat = pd.concat([df_Region1, df_Region2], axis=0, ignore_index=True)
print(df_concat)
# Out:
#    CustomerID    Name
# 0           1  Ramesh
# 1           2  Suresh
# 2           3    Babu
# 3           4   Shyam
