# %% [markdown]
# ## WHAT IS A FUNCTION?
# - FUNCTION IS A GROUP OF STATEMENTS THAT PERFORMS A SPECIFIC TASK.
# - A FUNCTION IS A COLLECTION OF STATEMENTS GROUPED TOGETHER THAT PERFORMS AN OPERATION.
#   WHEN YOU CALL THE RANDOM.RANDINT(A,B) FUNCTION,
#   FOR EXAMPLE THE SYSTEM ACTUALLY EXECUTES THE STATEMENTS IN THE FUNCTION AND RETURNS THE RESULT.
#
# ## ADVANTAGES OF FUNCTIONS:
# - MAKES YOUR CODE MORE ORGANIZED AND MANAGEABLE.
# - ENSURES RESUABILITY, AVOIDS CODE REDUNDENCY.

# %%
def hello():
    print('Hello')
    print('This is a function which does not take any argument')
    print('This function does not return any result')

# %%
hello()
# Out:
# Hello
# This is a function which does not take any argument
# This function does not return any result

# %%
hello(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hello(a)
#
# NameError: name 'a' is not defined

# %%
def even_odd(num):
    if num%2==0:
        print(num,' is Even')
    else:
        print(num,' is Odd')

# %%
even_odd(67)
# Out:
# 67  is Odd

# %%
def add(num1,num2):
    result = num1+num2
    return result

# %%
add(6,4)
# Out:
# 10

# %%
def add(num1,num2):
    result = 4+6
    print(result)

# %%
add(4,6)
# Out:
# 10

# %%
add(2,3)
# Out:
# 10

# %%
def add(num1,num2):
    result = num1+num2
    print(result)

# %%
add(2,3)
# Out:
# 5

# %%
result = add(2,3)
# Out:
# 5

# %%
result

# %%
print(result)
# Out:
# None

# %%
def add(num1,num2):
    result = num1+num2
    return result

# %%
add(2,3)
# Out:
# 5

# %%
result = add(2,3)

# %%
print(result)
# Out:
# 5

# %%
def largest_num(a,b,c):
    if a>b and a>c:
        print(a, 'is largest number')
    elif b>c:
        print(b, 'is largest num')
    else:
        print(c, 'is largest num')

# %%
largest_num(2,6,3)
# Out:
# 6 is largest num

# %%
def compare_strings(s1,s2):
    if len(s1)>len(s2):
        return s1, len(s1)
    else:
        return s2, len(s2)

# %%
compare_strings('rakhi','Eth ans')
# Out:
# ('Eth ans', 7)

# %%
def compare_strings(s1,s2):
    l1 = len(s1)-s1.count(' ')
    l2 = len(s2)-s2.count(' ')
    if l1>l2:
        return s1, l1
    else:
        return s2, l2

# %%
compare_strings('good morning','how are you?')
# Out:
# ('good morning', 11)

# %%
## count words in string using split function

# %% [markdown]
# ## DEFAULT PARAMETERS

# %%
def divide(num1,num2=2):
    return num1/num2

# %%
divide(56,4)
# Out:
# 14.0

# %%
divide(56)          # by default parameter is 2 as given above
# Out:
# 28.0

# %%
def divide(num1=2,num2):
    return num1/num2
# Out:
#   Cell In[59], line 1
#     def divide(num1=2,num2):
#                       ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def divide(num1=1,num2=1):
    return num1/num2

# %%
divide()
# Out:
# 1.0

# %%
def divide(num1=1,num2=2):
    return num1/num2

# %%
divide()
# Out:
# 0.5

# %% [markdown]
# ### POSITIONAL ARGUMENT AND KEYWORD ARGUMENTS

# %%
def details(name,age,city):
    print('The Details Are:')
    print('Name:',name)
    print('Age:',age)
    print('City:',city)

# %%
details('Rakhi',23,'Pune')        # positional argument
# Out:
# The Details Are:
# Name: Rakhi
# Age: 23
# City: Pune

# %%
details(23,'Pune','rakhi')
# Out:
# The Details Are:
# Name: 23
# Age: Pune
# City: rakhi

# %%
details(age = 23, city = 'Pune', name='Rakhi')       # keyword argument
# Out:
# The Details Are:
# Name: Rakhi
# Age: 23
# City: Pune

# %% [markdown]
# ### VARIABLE ARGUMENTS AND KEYWORD ARGUMENTS (ARGS AND KWARGS)

# %%
def add(num1,num2):
    result = num1+num2
    print(result)

# %%
add(2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 add(2,3,4)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(*nums):
    result = 0
    for i in nums:
        result += i
    return result

# %%
add(3)
# Out:
# 3

# %%
add(2,3,4)
# Out:
# 9

# %%
add(1,2,3,4,5,6,7,8,9)
# Out:
# 45

# %%
def person(**details):
    print('The Details are :')
    for i,j in details.items():
        print(i,':',j)

# %%
person(Name = 'Rakhi')
# Out:
# The Details are :
# Name : Rakhi

# %%
person(Name = 'Rakhi',city = 'Pune',salary = 1000)
# Out:
# The Details are :
# Name : Rakhi
# city : Pune
# salary : 1000
